# %% [markdown]
# ## 이미 생성된 합성 데이터셋 불러오기

# %%
## 이미 생성된 합성 데이터셋 생성
import pandas as pd

# 같은 폴더(현재 작업 디렉토리)에 저장했다면  ㅐ
dataset_df = pd.read_csv("./dataset.csv")
print(dataset_df.shape)
display(dataset_df)
# Out:
# (20, 3)
#                                            user_input  \
# 0           Analytics Hub 게시자와 목록 관리자 역할의 차이점은 무엇인가요?
# 1   BigQuery Studio 저장된 쿼리에 공개 액세스 권한을 방지하려면 어떻게 해...
# 2    calendarId에 primary 키워드를 사용하면 어떤 캘린더에 접근할 수 있나요?
# 3                 Google Drive API v3의 서비스 엔드포인트가 궁금해
# 4   files.create 메서드의 최대 파일 크기와 허용되는 미디어 MIME 유형은 ...
# 5          Firebase scrypt 해시 비밀번호를 사용한 사용자 가져오는 방법은?
# 6            커스텀 인증 시스템으로 Firebase에 인증하려면 어떻게 해야 하나요?
# 7   Firestore에서 맵 필드에 대한 단일 필드 색인 예외를 설정하면, 하위 필드들...
# 8            Firebase의 updateTime 필드에 사용되는 시간 형식이 뭐야?
# 9           Firefox 58 환경에서 Gmail의 AMP 렌더링 기능이 호환되나요?
# 10             Gmail 자가 테스트를 할 때 DKIM 또는 SPF 인증이 필요해?
# 11  HTML 헤더에 스크립트 태그를 넣을 수 없을 때, 이메일 본문에 코드를 삽입하는 ...
# 12            OAuth에서 승인 사용자 인증 정보 만드는 방법 순서대로 알려주세요.
# 13  Google의 계정 간 보안 서비스를 사용하는데 디코딩된 보안 이벤트 토큰의 eve...
# 14  MAP 3D 스토리텔링의 '표지'를 구성하기 위해 config.json 파일에 직접...
# 15           GMSMapPoint의 좌표계에서 (0, 0)은 어떤 지점을 의미하나요?
# 16          People API의 RequestMask 필드에 무엇을 입력해야 하나요?
# 17  People API에 요청을 보내는 Python 스크립트를 어떻게 실행하고 구성해야...
# 18  Google Sheets의 SERIAL_NUMBER 형식으로 1900년 2월 1일 ...
# 19        YouTube Data API를 사용하는 프로젝트의 기본 할당량은 얼마인가요?
#
#                                    reference_contexts  \
# 0   사용자가 다음 작업을 수행할 수 있게 해주는 Analytics Hub 게시자 역할(...
# 1   BigQuery Studio 저장된 쿼리에 공개 액세스 권한이 부여되지 않도록 하려...
# 2   현재 로그인한 사용자의 기본 캘린더에 액세스하려면 'primary' 키워드를 사용하세요.
# 3   이 서비스에는 다음 서비스 엔드포인트가 포함되고, 그 아래의 모든 URI가 이 서비...
# 4   최대 파일 크기: 5,120GB\r\n허용되는 미디어 MIME 유형: */*\r\n...
# 5   기본적으로 Firebase는 scrypt 해싱 알고리즘의 수정된 Firebase 버...
# 6   Firebase 인증에 맞춤 인증 시스템을 통합할 수 있습니다. 사용자가 정상적으로...
# 7   맵 필드에 단일 필드 색인 예외를 만들면 맵의 하위 필드에서 해당 설정을 상속합니다...
# 8   Uses RFC 3339, where generated output will alw...
# 9   브라우저 최소 버전\r\nChrome 69\r\nEdge 지원되지 않음\r\nFir...
# 10                 DKIM 또는 SPF 인증 자체 테스트에는 여전히 필요합니다.
# 11  이메일 구성 방식에 따라 이메일 본문의 할인/제품을 담당하는 시스템은 HTML 헤더...
# 12  1. 클라이언트 만들기를 클릭합니다. 2. TV 및 입력 제한 기기 애플리케이션 유...
# 13  events 클레임에는 토큰이 나타내는 보안 이벤트에 관한 정보가 포함됩니다. 이 ...
# 14  또한 구성 파일이 있는 경우 파일에 다음 섹션을 직접 추가할 수 있습니다.\r\n\...
# 15                   (0, 0) is the center of the map.
# 16                                     지원 중단된 서비스입니다.
# 17  Python용 Google 클라이언트 라이브러리를 설치합니다.\r\npip inst...
# 18  날짜, 시간, 날짜/시간, 기간 필드를 Lotus 1-2-3에서 대중화한 '일련번호...
# 19  YouTube Data API를 사용 설정한 프로젝트의 기본 할당량은 일일 10,0...
#
#                                             reference
# 0   Analytics Hub 게시자 역할은 목록을 생성, 업데이트, 삭제하고 목록에 I...
# 1   BigQuery Studio 저장된 쿼리에 공개 액세스 권한을 방지하려면 프로젝트에...
# 2   calendarId에 primary 키워드를 사용하면 현재 로그인한 사용자의 기본 ...
# 3   Google Drive API v3의 서비스 엔드포인트는 https://www.go...
# 4   files.create 메서드의 최대 파일 크기는 5,120GB입니다. 허용되는 미...
# 5   Firebase scrypt 해시 비밀번호를 사용한 사용자를 가져오려면, 먼저 Fi...
# 6   커스텀 인증 시스템으로 Firebase에 인증하려면, 먼저 인증 서버에서 사용자의 ...
# 7   네, Firestore에서 맵 필드에 단일 필드 색인 예외를 만들면 맵의 하위 필드...
# 8   Firebase의 updateTime 필드에는 RFC 3339 시간 형식이 사용됩니...
# 9   네, Firefox 58 환경에서는 Gmail의 AMP 렌더링 기능이 호환됩니다. ...
# 10    네, Gmail 자가 테스트를 할 때 DKIM 또는 SPF 인증이 여전히 필요합니다.
# 11  HTML 헤더에 스크립트 태그를 넣을 수 없는 경우, 이메일 본문에 스크립트 태그의...
# 12  OAuth에서 승인 사용자 인증 정보를 만드는 방법은 다음과 같습니다. 먼저, '클...
# 13  디코딩된 보안 이벤트 토큰의 events 클레임에는 토큰이 나타내는 보안 이벤트에 ...
# 14  MAP 3D 스토리텔링의 '표지'를 구성하기 위해 config.json 파일에 직접...
# 15           (0, 0)은 GMSMapPoint 좌표계에서 지도의 중심을 의미합니다.
# 16              지원 중단되었습니다. 대신 personFields를 사용해 주세요.
# 17  People API에 요청을 보내는 Python 스크립트를 실행하고 구성하려면 다음...
# 18  Google Sheets의 SERIAL_NUMBER 형식에서 1900년 2월 1일 ...
# 19  YouTube Data API를 사용하는 프로젝트의 기본 할당량은 일일 10,000...

# %%
# 테스트용으로 줄여서 했습니다. 이후 테스트할땐 실행 안하셔도 됩니다.

# dataset_df = dataset_df[:4]
# display(dataset_df)

# %% [markdown]
# ## 우리가 쓰는 RAG 체인 불러오기

# %%
from pathlib import Path
import sys

root = Path.cwd()
while not (root / "utils_final2").exists() and root != root.parent:
    root = root.parent
sys.path.insert(0, str(root))

from utils_final2.main3 import run_langraph
# Out:
# BM25 인덱스 없음 → 새로 생성: C:\Users\playdata\Documents\1_ai\Perplexity\utils_final2\bm25_index.pkl
# C:\Users\playdata\Documents\1_ai\Perplexity\utils_final2\retriever.py:51: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vs = Chroma(
# BM25 인덱스 없음 → 새로 생성: C:\Users\playdata\Documents\1_ai\Perplexity\utils_final2\bm25_qa_index.pkl
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 9
#       6     root = root.parent
#       7 sys.path.insert(0, str(root))
# ----> 9 from utils_final2.main3 import run_langraph
#
# File ~\Documents\1_ai\Perplexity\utils_final2\main3.py:1
# ----> 1 from .langgraph_setting2 import graph_setting
#       3 graph = graph_setting()
#       6 def run_langraph(user_input, config_id, image, chat_history=None):
#
# File ~\Documents\1_ai\Perplexity\utils_final2\langgraph_setting2.py:5
#       3 from .retriever import retriever_setting
#       4 from langgraph.checkpoint.memory import MemorySaver
# ----> 5 from .langgraph_node2 import *
#       9 # 그래프 설정
#      10 def graph_setting():
#      11     # LangGraph 정의
#
# File ~\Documents\1_ai\Perplexity\utils_final2\langgraph_node2.py:16
#      14 from .retriever import retriever_setting
#      15 from .retriever_qa import retriever_setting2
# ---> 16 from .retriever_hybrid import hybrid_retriever_setting, hybrid_retriever_setting_qa
#      18 import openai
#      19 from dotenv import load_dotenv
#
# File ~\Documents\1_ai\Perplexity\utils_final2\retriever_hybrid.py:7
#       5 from .retriever import retriever_setting
#       6 from .retriever_qa import retriever_setting2
# ----> 7 from .retriever_bm25 import bm25_retrievers_by_tag, bm25_retrievers_by_tag_qa
#       9 _vs = retriever_setting()
#      10 _vs_qa = retriever_setting2()
#
# File ~\Documents\1_ai\Perplexity\utils_final2\retriever_bm25.py:43
#      41 # 시작 시 로드
#      42 BM25_INDEX = _load_bm25_index(INDEX_FILE_PATH, retriever_setting)
# ---> 43 BM25_QA_INDEX = _load_bm25_index(QA_INDEX_FILE_PATH, retriever_setting2)
#      45 def bm25_retrievers_by_tag(k=5):
#      46     for r in BM25_INDEX.values():
#
# File ~\Documents\1_ai\Perplexity\utils_final2\retriever_bm25.py:24, in _load_bm25_index(path, retriever_func)
#      22 else:
#      23     print(f"BM25 인덱스 없음 → 새로 생성: {path}")
# ---> 24     vs = retriever_func()
#      25     data = vs.get(include=["documents", "metadatas"])
#      26     docs, metas = data["documents"], data["metadatas"]
#
# File ~\Documents\1_ai\Perplexity\utils_final2\retriever_qa.py:47, in retriever_setting2(force_download)
#      44             need_download = True
#      46 if need_download:
# ---> 47     create_chroma_db()
#      49 # 기존 크로마 벡터스토어 로드
#      50 vs = Chroma(
#      51     collection_name=COLLECTION_NAME,  # DB 생성 시 컬렉션명과 동일해야 함
#      52     persist_directory=DB_DIR,
#      53     embedding_function=embeddings,
#      54 )
#
# File ~\Documents\1_ai\Perplexity\utils_final2\vector_db_qa.py:118, in create_chroma_db()
#     113 FOLDER_URL = (
#     114     "https://drive.google.com/drive/folders/1AFn1z1Lu9olzlBe1Ln4L88WhmpzTHnAj?usp=drive_link"
#     115 )
#     116 target_path = HERE / "qa_chroma_db"
# --> 118 download_drive_folder_to_chroma_db(FOLDER_URL, target_path)
#
# File ~\Documents\1_ai\Perplexity\utils_final2\vector_db_qa.py:22, in download_drive_folder_to_chroma_db(folder_url, target_dir)
#      19     import os
#      21     os.environ["GDOWN_USE_COOKIES"] = "False"
# ---> 22     gdown.download_folder(
#      23         url=folder_url, output=td, quiet=True, use_cookies=False
#      24     )
#      25     success = True
#      26 except Exception:
#
# File ~\anaconda3\envs\teamproject\Lib\site-packages\gdown\download_folder.py:325, in download_folder(url, id, output, quiet, proxy, speed, use_cookies, remaining_ok, verify, user_agent, skip_download, resume)
#     322     files.append(local_path)
#     323     continue
# --> 325 local_path = download(
#     326     url="https://drive.google.com/uc?id=" + id,
#     327     output=local_path,
#     328     quiet=quiet,
#     329     proxy=proxy,
#     330     speed=speed,
#     331     use_cookies=use_cookies,
#     332     verify=verify,
#     333     resume=resume,
#     334 )
#     335 if local_path is None:
#     336     if not quiet:
#
# File ~\anaconda3\envs\teamproject\Lib\site-packages\gdown\download.py:202, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format, user_agent, log_messages)
#     199     is_gdrive_download_link = True
#     201 while True:
# --> 202     res = sess.get(url, stream=True, verify=verify)
#     204     if not (gdrive_file_id and is_gdrive_download_link):
#     205         break
#
# File ~\anaconda3\envs\teamproject\Lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~\anaconda3\envs\teamproject\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\envs\teamproject\Lib\site-packages\requests\sessions.py:724, in Session.send(self, request, **kwargs)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File ~\anaconda3\envs\teamproject\Lib\site-packages\requests\sessions.py:724, in <listcomp>(.0)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File ~\anaconda3\envs\teamproject\Lib\site-packages\requests\sessions.py:265, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 265     resp = self.send(
#     266         req,
#     267         stream=stream,
#     268         timeout=timeout,
#     269         verify=verify,
#     270         cert=cert,
#     271         proxies=proxies,
#     272         allow_redirects=False,
#     273         **adapter_kwargs,
#     274     )
#     276     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     278     # extract redirect url, if any, for the next loop
#
# File ~\anaconda3\envs\teamproject\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\envs\teamproject\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\envs\teamproject\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\anaconda3\envs\teamproject\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\anaconda3\envs\teamproject\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~\anaconda3\envs\teamproject\Lib\http\client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File ~\anaconda3\envs\teamproject\Lib\http\client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File ~\anaconda3\envs\teamproject\Lib\http\client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File ~\anaconda3\envs\teamproject\Lib\socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# File ~\anaconda3\envs\teamproject\Lib\ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\envs\teamproject\Lib\ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## RAG 및 퍼플렉시티 비교

# %% [markdown]
# ### 정성적 평가 체인

# %% [markdown]
# 정확도: 정답과 맞는지 여부
#
# 재현율: 정답의 요소를 얼마나 빠짐없이 담았는지
#
# 신뢰성: 추측이나 헛소리 없이 정답 기반인지

# %%
import os
import json
import pandas as pd
import numpy as np
from openai import OpenAI
from dotenv import load_dotenv

# 환경 변수 불러오기
load_dotenv()
client = OpenAI()

def api_answer_evaluation(question: str, answer: str, system_answer: str):
    prompt = f"""
당신은 AI가 생성한 답변이 **기준 정답**과 의미적으로 얼마나 잘 일치하는지를 평가하는 전문가입니다.
이 평가는 **정답과 문장이 달라도 핵심 내용에 대한 의미가 같다면 인정**합니다.
하지만 기준 정답에 **없는 정보**, **추측**, **불필요한 코드**는 감점 요인입니다.

---

**평가 원칙**:

- 답변이 **기준 정답과 단어/문장이 다르더라도**, 핵심 내용의 의미가 같으면 높은 점수를 줘야 합니다.
- 특히 **웹 기반 배경 설명**, **예측성 문장**, **불필요한 코드 예시**는 감점합니다.
- **핵심 정보(조건, 함수명, 파라미터 등)**는 꼭 포함되어야 합니다.

---

**평가 항목**:

1. **정확도 (Accuracy)**:
- 3점: 표현은 달라도 기준 정답과 **의미가 동일**
- 2점: 핵심은 일치하지만, 일부 세부 의미나 조건이 다름
- 1점: 중요한 내용은 있으나 일부 왜곡되었거나 혼동 있음
- 0점: 기준 정답과 **의미적으로도 불일치**하거나 틀림

2. **재현율 (Recall)**:
- 3점: 기준 정답의 **핵심 정보(논리, 순서, 구성요소)**를 빠짐없이 포함
- 2점: 주요 정보는 있지만 일부가 빠짐
- 1점: 핵심 정보 일부만 존재하거나 흐릿하게 표현됨
- 0점: 기준 정답의 중요한 내용이 대부분 빠짐

3. **신뢰성 (Reliability)**:
- 3점: **기준 정답 안에서만 충실하게** 답변 (부가 설명 없음)
- 2점: 대체로 맞지만, 부가 설명이 약간 포함됨
- 1점: 일반 지식, 예시 코드, 추측성 문장 등 기준 외 정보 포함
- 0점: 기준 정답과 무관하거나 과한 배경설명이 많음

---

**출력은 반드시 아래와 같이 JSON 형식으로만 하세요**:

```json
{{
  "accuracy": 3,
  "recall": 2,
  "reliability": 1
}}

## 사용자 질문 : {question}
## 기준 정답 : {answer}
## 시스템 답변 : {system_answer}
"""

    response = client.chat.completions.create(
        model="gpt-4.1",
        temperature=0,
        response_format={"type": "json_object"},
        messages=[
            {"role": "system", "content": "당신은 API 문서 기반 RAG 답변 평가 전문가이다."},
            {"role": "user", "content": prompt},
        ]
    )

    return response.choices[0].message.content

# %%
dataset_df = pd.read_csv("rag_with_answers.csv")

# %%
display(dataset_df)
# Out:
#                                            user_input  \
# 0           Analytics Hub 게시자와 목록 관리자 역할의 차이점은 무엇인가요?
# 1   BigQuery Studio 저장된 쿼리에 공개 액세스 권한을 방지하려면 어떻게 해...
# 2    calendarId에 primary 키워드를 사용하면 어떤 캘린더에 접근할 수 있나요?
# 3                 Google Drive API v3의 서비스 엔드포인트가 궁금해
# 4   files.create 메서드의 최대 파일 크기와 허용되는 미디어 MIME 유형은 ...
# 5          Firebase scrypt 해시 비밀번호를 사용한 사용자 가져오는 방법은?
# 6            커스텀 인증 시스템으로 Firebase에 인증하려면 어떻게 해야 하나요?
# 7   Firestore에서 맵 필드에 대한 단일 필드 색인 예외를 설정하면, 하위 필드들...
# 8            Firebase의 updateTime 필드에 사용되는 시간 형식이 뭐야?
# 9           Firefox 58 환경에서 Gmail의 AMP 렌더링 기능이 호환되나요?
# 10             Gmail 자가 테스트를 할 때 DKIM 또는 SPF 인증이 필요해?
# 11  HTML 헤더에 스크립트 태그를 넣을 수 없을 때, 이메일 본문에 코드를 삽입하는 ...
# 12            OAuth에서 승인 사용자 인증 정보 만드는 방법 순서대로 알려주세요.
# 13  Google의 계정 간 보안 서비스를 사용하는데 디코딩된 보안 이벤트 토큰의 eve...
# 14  MAP 3D 스토리텔링의 '표지'를 구성하기 위해 config.json 파일에 직접...
# 15           GMSMapPoint의 좌표계에서 (0, 0)은 어떤 지점을 의미하나요?
# 16          People API의 RequestMask 필드에 무엇을 입력해야 하나요?
# 17  People API에 요청을 보내는 Python 스크립트를 어떻게 실행하고 구성해야...
# 18  Google Sheets의 SERIAL_NUMBER 형식으로 1900년 2월 1일 ...
# 19        YouTube Data API를 사용하는 프로젝트의 기본 할당량은 얼마인가요?
#
#                                    reference_contexts  \
# 0   사용자가 다음 작업을 수행할 수 있게 해주는 Analytics Hub 게시자 역할(...
# 1   BigQuery Studio 저장된 쿼리에 공개 액세스 권한이 부여되지 않도록 하려...
# 2   현재 로그인한 사용자의 기본 캘린더에 액세스하려면 'primary' 키워드를 사용하세요.
# 3   이 서비스에는 다음 서비스 엔드포인트가 포함되고, 그 아래의 모든 URI가 이 서비...
# 4   최대 파일 크기: 5,120GB\r\n허용되는 미디어 MIME 유형: */*\r\n...
# 5   기본적으로 Firebase는 scrypt 해싱 알고리즘의 수정된 Firebase 버...
# 6   Firebase 인증에 맞춤 인증 시스템을 통합할 수 있습니다. 사용자가 정상적으로...
# 7   맵 필드에 단일 필드 색인 예외를 만들면 맵의 하위 필드에서 해당 설정을 상속합니다...
# 8   Uses RFC 3339, where generated output will alw...
# 9   브라우저 최소 버전\r\nChrome 69\r\nEdge 지원되지 않음\r\nFir...
# 10                 DKIM 또는 SPF 인증 자체 테스트에는 여전히 필요합니다.
# 11  이메일 구성 방식에 따라 이메일 본문의 할인/제품을 담당하는 시스템은 HTML 헤더...
# 12  1. 클라이언트 만들기를 클릭합니다. 2. TV 및 입력 제한 기기 애플리케이션 유...
# 13  events 클레임에는 토큰이 나타내는 보안 이벤트에 관한 정보가 포함됩니다. 이 ...
# 14  또한 구성 파일이 있는 경우 파일에 다음 섹션을 직접 추가할 수 있습니다.\r\n\...
# 15                   (0, 0) is the center of the map.
# 16                                     지원 중단된 서비스입니다.
# 17  Python용 Google 클라이언트 라이브러리를 설치합니다.\r\npip inst...
# 18  날짜, 시간, 날짜/시간, 기간 필드를 Lotus 1-2-3에서 대중화한 '일련번호...
# 19  YouTube Data API를 사용 설정한 프로젝트의 기본 할당량은 일일 10,0...
#
#                                             reference  \
# 0   Analytics Hub 게시자 역할은 목록을 생성, 업데이트, 삭제하고 목록에 I...
# 1   BigQuery Studio 저장된 쿼리에 공개 액세스 권한을 방지하려면 프로젝트에...
# 2   calendarId에 primary 키워드를 사용하면 현재 로그인한 사용자의 기본 ...
# 3   Google Drive API v3의 서비스 엔드포인트는 https://www.go...
# 4   files.create 메서드의 최대 파일 크기는 5,120GB입니다. 허용되는 미...
# 5   Firebase scrypt 해시 비밀번호를 사용한 사용자를 가져오려면, 먼저 Fi...
# 6   커스텀 인증 시스템으로 Firebase에 인증하려면, 먼저 인증 서버에서 사용자의 ...
# 7   네, Firestore에서 맵 필드에 단일 필드 색인 예외를 만들면 맵의 하위 필드...
# 8   Firebase의 updateTime 필드에는 RFC 3339 시간 형식이 사용됩니...
# 9   네, Firefox 58 환경에서는 Gmail의 AMP 렌더링 기능이 호환됩니다. ...
# 10    네, Gmail 자가 테스트를 할 때 DKIM 또는 SPF 인증이 여전히 필요합니다.
# 11  HTML 헤더에 스크립트 태그를 넣을 수 없는 경우, 이메일 본문에 스크립트 태그의...
# 12  OAuth에서 승인 사용자 인증 정보를 만드는 방법은 다음과 같습니다. 먼저, '클...
# 13  디코딩된 보안 이벤트 토큰의 events 클레임에는 토큰이 나타내는 보안 이벤트에 ...
# 14  MAP 3D 스토리텔링의 '표지'를 구성하기 위해 config.json 파일에 직접...
# 15           (0, 0)은 GMSMapPoint 좌표계에서 지도의 중심을 의미합니다.
# 16              지원 중단되었습니다. 대신 personFields를 사용해 주세요.
# 17  People API에 요청을 보내는 Python 스크립트를 실행하고 구성하려면 다음...
# 18  Google Sheets의 SERIAL_NUMBER 형식에서 1900년 2월 1일 ...
# 19  YouTube Data API를 사용하는 프로젝트의 기본 할당량은 일일 10,000...
#
#                                         system_answer
# 0   Analytics Hub 게시자 역할과 목록 관리자 역할의 차이점은 다음과 같습니다...
# 1   BigQuery Studio 저장된 쿼리에 대한 공개 액세스 권한을 방지하려면 프로...
# 2   현재 로그인한 사용자의 기본 캘린더에 접근할 수 있습니다. `primary` 키워드...
# 3   Google Drive API v3의 서비스 엔드포인트는 `https://www.g...
# 4   files.create 메서드를 사용하여 파일을 업로드할 때 지원되는 최대 파일 크...
# 5   Firebase scrypt 해시 비밀번호를 사용한 사용자를 가져오려면 Fireba...
# 6   Firebase에 커스텀 인증 시스템을 통합하려면 다음 단계를 따르세요:\r\n\r...
# 7   네, Firestore에서 맵 필드에 단일 필드 색인 예외를 설정하면, 맵의 하위 ...
# 8   Firebase의 `updateTime` 필드에 사용되는 시간 형식은 RFC 333...
# 9   네, Firefox 58 환경에서는 Gmail의 AMP 렌더링 기능이 호환됩니다. ...
# 10  네, Gmail 자가 테스트를 할 때 DKIM 또는 SPF 인증이 여전히 필요합니다...
# 11  이메일 본문에 스크립트 태그를 삽입할 때, HTML 헤더에 스크립트 태그를 넣을 수...
# 12  OAuth 2.0을 사용하여 승인 사용자 인증 정보를 만드는 방법은 다음과 같습니다...
# 13  Google의 계정 간 보안 서비스를 사용할 때, 디코딩된 보안 이벤트 토큰의 `e...
# 14  3D 스토리텔링의 '표지'를 구성하기 위해 config.json 파일에 직접 추가할...
# 15  죄송합니다. 제공된 문서에는 GMSMapPoint의 좌표계에서 (0, 0)이 어떤 ...
# 16  People API의 RequestMask 필드는 지원 중단되었습니다. 대신, pe...
# 17  People API에 요청을 보내는 Python 스크립트를 실행하고 구성하는 방법은...
# 18  1900년 2월 1일 오후 5시의 경우 SERIAL_NUMBER 형식으로 계산하면 ...
# 19  YouTube Data API를 사용 설정한 프로젝트의 기본 할당량은 일일 10,0...

# %%
evaluation_results = []

for idx in range(len(dataset_df)):
    question = dataset_df['user_input'][idx]
    answer = dataset_df['reference'][idx]
    system_answer = dataset_df['system_answer'][idx]

    # 평가 수행 (OpenAI 호출)
    response = api_answer_evaluation(question, answer, system_answer)

    try:
        scores = json.loads(response)
        evaluation_results.append({
            'index': idx,
            'question': question,
            'reference': answer,
            'system_answer': system_answer,
            'accuracy': scores.get('accuracy', 0),
            'recall': scores.get('recall', 0),
            'reliability': scores.get('reliability', 0)
        })
        print(f"평가 완료: {idx+1}/{len(dataset_df)} - Accuracy: {scores.get('accuracy', 0)}")
    except json.JSONDecodeError:
        print(f"JSON 파싱 오류: {idx+1}/{len(dataset_df)}")
        evaluation_results.append({
            'index': idx,
            'question': question,
            'reference': answer,
            'system_answer': system_answer,
            'accuracy': 0,
            'recall': 0,
            'reliability': 0
        })

# 결과 DataFrame 변환
results_df = pd.DataFrame(evaluation_results)

# 평균 점수 계산
avg_accuracy = results_df['accuracy'].mean() * 100 / 3
avg_recall = results_df['recall'].mean() * 100 / 3
avg_reliability = results_df['reliability'].mean() * 100 / 3
overall_avg = (avg_accuracy + avg_recall + avg_reliability) / 3

print(f"\n=== 전체 평가 결과 ===")
print(f"평균 정확도: {avg_accuracy:.2f}")
print(f"평균 재현율: {avg_recall:.2f}")
print(f"평균 신뢰성: {avg_reliability:.2f}")
print(f"전체 평균: {overall_avg:.2f}")
# Out:
# 평가 완료: 1/20 - Accuracy: 3
# 평가 완료: 2/20 - Accuracy: 3
# 평가 완료: 3/20 - Accuracy: 3
# 평가 완료: 4/20 - Accuracy: 2
# 평가 완료: 5/20 - Accuracy: 3
# 평가 완료: 6/20 - Accuracy: 3
# 평가 완료: 7/20 - Accuracy: 2
# 평가 완료: 8/20 - Accuracy: 3
# 평가 완료: 9/20 - Accuracy: 3
# 평가 완료: 10/20 - Accuracy: 3
# 평가 완료: 11/20 - Accuracy: 3
# 평가 완료: 12/20 - Accuracy: 2
# 평가 완료: 13/20 - Accuracy: 2
# 평가 완료: 14/20 - Accuracy: 3
# 평가 완료: 15/20 - Accuracy: 2
# 평가 완료: 16/20 - Accuracy: 0
# 평가 완료: 17/20 - Accuracy: 2
# 평가 완료: 18/20 - Accuracy: 2
# 평가 완료: 19/20 - Accuracy: 3
# 평가 완료: 20/20 - Accuracy: 3
#
# === 전체 평가 결과 ===
# 평균 정확도: 83.33
# 평균 재현율: 76.67
# 평균 신뢰성: 61.67
# 전체 평균: 73.89

# %%
print(f"\n=== 전체 평가 결과 ===")
print(f"평균 정확도: {avg_accuracy:.2f}")
print(f"평균 재현율: {avg_recall:.2f}")
print(f"평균 신뢰성: {avg_reliability:.2f}")
print(f"전체 평균: {overall_avg:.2f}")
# Out:
# === 전체 평가 결과 ===
# 평균 정확도: 83.33
# 평균 재현율: 76.67
# 평균 신뢰성: 61.67
# 전체 평균: 73.89

# %% [markdown]
# ## 퍼플렉시티 응답을 배치로 정성적 평가

# %%
from langchain_community.chat_models import ChatPerplexity

llm = ChatPerplexity(model="sonar")

# %%
# === 배치 평가 실행 ===
evaluation_results = []

for idx in range(len(dataset_df)):
    question = dataset_df['user_input'][idx]
    answer = dataset_df['reference'][idx]

    # 시스템 답변 생성
    system_answer = llm.invoke(question).content

    # 평가 수행 (OpenAI 호출)
    response = api_answer_evaluation(question, answer, system_answer)

    # JSON 파싱
    try:
        scores = json.loads(response)
        evaluation_results.append({
            'index': idx,
            'question': question,
            'reference': answer,
            'system_answer': system_answer,
            'accuracy': scores.get('accuracy', 0),
            'recall': scores.get('recall', 0),
            'reliability': scores.get('reliability', 0)
        })
        print(f"평가 완료: {idx+1}/{len(dataset_df)} - Accuracy: {scores.get('accuracy', 0)}")
    except json.JSONDecodeError:
        print(f"JSON 파싱 오류: {idx+1}/{len(dataset_df)}")
        evaluation_results.append({
            'index': idx,
            'question': question,
            'reference': answer,
            'system_answer': system_answer,
            'accuracy': 0,
            'recall': 0,
            'reliability': 0
        })

# 결과 DataFrame 변환
results_df = pd.DataFrame(evaluation_results)

# 평균 점수 계산
avg_accuracy = results_df['accuracy'].mean()*100/3
avg_recall = results_df['recall'].mean()*100/3
avg_reliability = results_df['reliability'].mean()*100/3
overall_avg = (avg_accuracy + avg_recall + avg_reliability) / 3

print(f"\n=== 전체 평가 결과 ===")
print(f"평균 정확도: {avg_accuracy:.2f}")
print(f"평균 재현율: {avg_recall:.2f}")
print(f"평균 신뢰성: {avg_reliability:.2f}")
print(f"전체 평균: {overall_avg:.2f}")

# 결과 저장
# results_df.to_csv('perplexity_batch_evaluation_results.csv', index=False)
# print(f"\n결과가 'perplexity_batch_evaluation_results.csv'에 저장되었습니다.")
# Out:
# 평가 완료: 1/20 - Accuracy: 3
# 평가 완료: 2/20 - Accuracy: 2
# 평가 완료: 3/20 - Accuracy: 3
# 평가 완료: 4/20 - Accuracy: 2
# 평가 완료: 5/20 - Accuracy: 2
# 평가 완료: 6/20 - Accuracy: 3
# 평가 완료: 7/20 - Accuracy: 3
# 평가 완료: 8/20 - Accuracy: 3
# 평가 완료: 9/20 - Accuracy: 1
# 평가 완료: 10/20 - Accuracy: 3
# 평가 완료: 11/20 - Accuracy: 3
# 평가 완료: 12/20 - Accuracy: 0
# 평가 완료: 13/20 - Accuracy: 1
# 평가 완료: 14/20 - Accuracy: 1
# 평가 완료: 15/20 - Accuracy: 3
# 평가 완료: 16/20 - Accuracy: 0
# 평가 완료: 17/20 - Accuracy: 1
# 평가 완료: 18/20 - Accuracy: 2
# 평가 완료: 19/20 - Accuracy: 1
# 평가 완료: 20/20 - Accuracy: 3
#
# === 전체 평가 결과 ===
# 평균 정확도: 66.67
# 평균 재현율: 58.33
# 평균 신체성: 33.33
# 전체 평균: 52.78
